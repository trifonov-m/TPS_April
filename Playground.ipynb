# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Чтение файлов

# %%
train = pd.read_csv('data/train.csv', index_col='PassengerId')
train.head()
# Out:
#              Survived  Pclass              Name   Sex    Age  SibSp  Parch  \
# PassengerId
# 0                   1       1  Oconnor, Frankie  male    NaN      2      0
# 1                   0       3       Bryan, Drew  male    NaN      0      0
# 2                   0       3    Owens, Kenneth  male   0.33      1      2
# 3                   0       3     Kramer, James  male  19.00      0      0
# 4                   1       3     Bond, Michael  male  25.00      0      0
#
#                 Ticket   Fare   Cabin Embarked
# PassengerId
# 0               209245  27.14  C12239        S
# 1                27323  13.35     NaN        S
# 2            CA 457703  71.29     NaN        S
# 3             A. 10866  13.04     NaN        S
# 4               427635   7.76     NaN        S

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Survived  100000 non-null  int64
#  1   Pclass    100000 non-null  int64
#  2   Name      100000 non-null  object
#  3   Sex       100000 non-null  object
#  4   Age       96708 non-null   float64
#  5   SibSp     100000 non-null  int64
#  6   Parch     100000 non-null  int64
#  7   Ticket    95377 non-null   object
#  8   Fare      99866 non-null   float64
#  9   Cabin     32134 non-null   object
#  10  Embarked  99750 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 9.2+ MB

# %%
## Здесь test - то, на основании чего потом грузить submit
## train - для обучения модели - делить на test и valid
test = pd.read_csv('data/test.csv', index_col='PassengerId')
test.head()
# Out:
#              Pclass              Name     Sex   Age  SibSp  Parch  Ticket  \
# PassengerId
# 100000            3  Holliday, Daniel    male  19.0      0      0   24745
# 100001            3  Nguyen, Lorraine  female  53.0      0      0   13264
# 100002            1   Harris, Heather  female  19.0      0      0   25990
# 100003            2      Larsen, Eric    male  25.0      0      0  314011
# 100004            1     Cleary, Sarah  female  17.0      0      2   26203
#
#               Fare   Cabin Embarked
# PassengerId
# 100000       63.01     NaN        S
# 100001        5.81     NaN        S
# 100002       38.91  B15315        C
# 100003       12.93     NaN        S
# 100004       26.89  B22515        C

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Survived  100000 non-null  int64
#  1   Pclass    100000 non-null  int64
#  2   Name      100000 non-null  object
#  3   Sex       100000 non-null  object
#  4   Age       96708 non-null   float64
#  5   SibSp     100000 non-null  int64
#  6   Parch     100000 non-null  int64
#  7   Ticket    95377 non-null   object
#  8   Fare      99866 non-null   float64
#  9   Cabin     32134 non-null   object
#  10  Embarked  99750 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 9.2+ MB

# %%
submission = pd.read_csv('data/sample_submission.csv', index_col='PassengerId')
submission.head()
# Out:
#              Survived
# PassengerId
# 100000              1
# 100001              1
# 100002              1
# 100003              1
# 100004              1

# %%
submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 100000 to 199999
# Data columns (total 1 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   Survived  100000 non-null  int64
# dtypes: int64(1)
# memory usage: 1.5 MB

# %%
train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
cat_columns = ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
num_columns = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
label_train = train.copy()
label_test = test.copy()

label_encoder = LabelEncoder()
for col in cat_columns:
    label_encoder.fit(list(train[col].values) + list(test[col].values))
    label_train[col] = label_encoder.transform(train[col])
    label_test[col] = label_encoder.transform(test[col])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\kaggle\venv\lib\site-packages\sklearn\utils\_encode.py in _encode(values, uniques, check_unknown)
#     177         try:
# --> 178             return _map_to_integer(values, uniques)
#     179         except KeyError as e:
#
# E:\kaggle\venv\lib\site-packages\sklearn\utils\_encode.py in _map_to_integer(values, uniques)
#     122     table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 123     return np.array([table[v] for v in values])
#     124
#
# E:\kaggle\venv\lib\site-packages\sklearn\utils\_encode.py in <listcomp>(.0)
#     122     table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 123     return np.array([table[v] for v in values])
#     124
#
# E:\kaggle\venv\lib\site-packages\sklearn\utils\_encode.py in __missing__(self, key)
#     116             return self.nan_value
# ...
